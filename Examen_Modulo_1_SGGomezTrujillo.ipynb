# %% [markdown]
# #Creación de Clase Tienda On Line

# %%
class TiendaOnLine:
    
    def __init__(self, nombre):
        self.nombre = nombre
        self.inventario = []                                # Lista de diccionarios: cada dict es {"nombre": str, "precio": float, "cantidad": int}
        self.ventas_totales = 0
    
    def agregar_producto(self, nombre, precio, cantidad):
        # Validaciones
        if not nombre or not precio or not cantidad:
            print(f"Debes ingresar nombre, precio y cantidad del producto.\nEjecuta nuevamente.")
            return
        if precio <= 0:                                     #posibilidad de mejora, imposibilidad de ingreso de string.
            print("Debes ingresar un precio mayor a 0.")
            return
        if cantidad <= 0 or not isinstance(cantidad,int):   #posibilidad de mejora, imposibilidad de ingreso de string.
            print("Debes ingresar un número entero, mayor a 0.")
            return

        # Busqueda en el inventario
        for item in self.inventario:
            if item["nombre"] == nombre.title().strip():
                item["cantidad"] += cantidad
                print(f"Se actualizaron las unidades del producto '{nombre.title()}'. Hay {item['cantidad']:,.0f} unidad(es) disponible(s).") #title para corregir error de usuario.
                return
        
        # Si no existe, agregar nuevo producto
        nuevo_producto = {"nombre": nombre.title().strip(), "precio": precio, "cantidad": cantidad}
        self.inventario.append(nuevo_producto)
        print(f"El producto '{nombre.title().strip()}' fue agregado al inventario.")  #sin el title(), replica el nombre ingresado para corroborar con el usuario que fuera error de tipeo.
        self.ver_inventario()
    
    def ver_inventario(self):
        if not self.inventario:
            print("El inventario está vacío.")
            #return
        
        for producto in self.inventario:
            print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']:,.2f}, Cantidad: {producto['cantidad']:,.0f}") #corregido nombre-producto.

    def buscar_producto(self,nombre):
        
        prod = nombre.title().strip()   #renombrado nombre en prod para acceder al formato en que se registra en el diccionario.
        encontrado = False

        for producto in self.inventario:
            if prod == producto['nombre']:
                print(f"El producto '{prod}' se encuentra en el inventario.\nNombre: {producto['nombre']}, Precio: ${producto['precio']:,.2f}, Cantidad: {producto['cantidad']:,.0f}")
                encontrado = True

        if not encontrado:
            print(f"El producto '{prod}' no se encuentra en el inventario.")

    def actualizar_stock(self,nombre,cantidad):

        if not self.inventario:
            print(f"Debes ingresar un nombre de producto válido.")
            return

        if not isinstance(cantidad,int):
            print(f"No puedes indicar cantidades con decimales, deben ser números enteros.")
            return

        if cantidad == 0:
            print("La cantidad ingresada es 0(cero). No se modificó el stock.")

        for producto in self.inventario:

            if cantidad >0:
                if nombre.title().strip() == producto['nombre']:
                    producto['cantidad']+=cantidad
                    print(f"Se actualizó el stock:\nNombre: {producto['nombre']}, Precio: ${producto['precio']:,.2f}, Cantidad: {producto['cantidad']:,.0f}")
                    break

            else:
                if nombre.title().strip() == producto['nombre'] and (- cantidad) > producto['cantidad']:    #evita variación de stock menor a cero.
                    print(f"Sólo se pudo descontar {producto['cantidad']} unidad(es). El stock del producto está en 0(cero).")
                    producto['cantidad'] = 0
                    print(f"Nombre: {producto['nombre']}, Precio: ${producto['precio']:,.2f}, Cantidad: {producto['cantidad']:,.0f}")
                    break

        else:
            print(f"El producto '{nombre.title().strip()}', no se encuentra en el inventario.")

    def eliminar_producto(self,nombre):
        
        if not nombre:
            print("Debes ingresar un nombre de producto.")

        for producto in self.inventario:
            if nombre.title().strip() == producto['nombre']:
                self.inventario.remove(producto)
                print(f"El producto '{nombre}', se ha eliminado del inventario.")
                break
        else:
            print(f"El producto '{nombre.title().strip()}', no se encuentra en el inventario.")

    def calcular_valor_inventario(self):
        total_inventario=0
        for producto in self.inventario:
            valor=producto['precio']*producto['cantidad']
            total_inventario+=valor
        print(f"El valor total del inventario es de ${total_inventario:,.2f}.")

# %%
tester=TiendaOnLine("tester")

# %%
tester.ver_inventario()
# Out:
# El inventario está vacío.

# %%
tester.agregar_producto('jean',25.5,420)
# Out:
# El producto 'Jean' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# None

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420

# %%
tester.agregar_producto('remera',7.5,450)
tester.agregar_producto('vestido',12.48,14)
tester.agregar_producto('campera',34,22)
# Out:
# El producto 'Remera' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# None
# El producto 'Vestido' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 14
# None
# El producto 'Campera' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 14
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# None

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 14
# Nombre: Campera, Precio: $34.00, Cantidad: 22

# %%
tester.agregar_producto("VesTidO",12.50,50)
# Out:
# Se actualizaron las unidades del producto 'Vestido'. Hay 64 unidad(es) disponible(s).

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22

# %%
tester.agregar_producto('buzo',8.5,65)
tester.agregar_producto('sweater',14.8,29)
tester.agregar_producto('pollera',18,41)
tester.agregar_producto('camisa',24.71,53)
# Out:
# El producto 'Buzo' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 65
# None
# El producto 'Sweater' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 65
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# None
# El producto 'Pollera' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 65
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# Nombre: Pollera, Precio: $18.00, Cantidad: 41
# None
# El producto 'Camisa' fue agregado al inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 65
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# Nombre: Pollera, Precio: $18.00, Cantidad: 41
# Nombre: Camisa, Precio: $24.71, Cantidad: 53
# None

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 450
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 65
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# Nombre: Pollera, Precio: $18.00, Cantidad: 41
# Nombre: Camisa, Precio: $24.71, Cantidad: 53

# %%
tester.buscar_producto("Camiseta")
# Out:
# El producto 'Camiseta' no se encuentra en el inventario.

# %%
tester.buscar_producto("jean")
# Out:
# El producto 'Jean' se encuentra en el inventario.
# Nombre: Jean, Precio: $25.50, Cantidad: 420

# %%
tester.actualizar_stock("remera",90)
# Out:
# Se actualizó el stock:
# Nombre: Remera, Precio: $7.50, Cantidad: 540

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 540
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 65
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# Nombre: Pollera, Precio: $18.00, Cantidad: 41
# Nombre: Camisa, Precio: $24.71, Cantidad: 53

# %%
tester.actualizar_stock("jean",-100)
# Out:
# El producto 'Jean', no se encuentra en el inventario.

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 540
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 65
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# Nombre: Pollera, Precio: $18.00, Cantidad: 41
# Nombre: Camisa, Precio: $24.71, Cantidad: 53

# %%
tester.actualizar_stock('Buzo',-150)
# Out:
# Sólo se pudo descontar 65 unidad(es). El stock del producto está en 0(cero).
# Nombre: Buzo, Precio: $8.50, Cantidad: 0

# %%
tester.actualizar_stock("camisa",4)
# Out:
# Se actualizó el stock:
# Nombre: Camisa, Precio: $24.71, Cantidad: 57

# %%
tester.actualizar_stock("cardigan",30)
# Out:
# El producto 'Cardigan', no se encuentra en el inventario.

# %%
tester.actualizar_stock("camisa",45.36)
# Out:
# No puedes indicar cantidades con decimales, deben ser números enteros.

# %%
tester.actualizar_stock("",-50)
# Out:
# El producto '', no se encuentra en el inventario.

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 540
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Buzo, Precio: $8.50, Cantidad: 0
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# Nombre: Pollera, Precio: $18.00, Cantidad: 41
# Nombre: Camisa, Precio: $24.71, Cantidad: 57

# %%
tester.actualizar_stock("camisa",-60)
# Out:
# Sólo se pudo descontar 57 unidad(es). El stock del producto está en 0(cero).
# Nombre: Camisa, Precio: $24.71, Cantidad: 0

# %%
tester.eliminar_producto("casa")
# Out:
# El producto 'Casa', no se encuentra en el inventario.

# %%
tester.eliminar_producto("Buzo")
# Out:
# El producto 'Buzo', se ha eliminado del inventario.

# %%
tester.ver_inventario()
# Out:
# Nombre: Jean, Precio: $25.50, Cantidad: 420
# Nombre: Remera, Precio: $7.50, Cantidad: 540
# Nombre: Vestido, Precio: $12.48, Cantidad: 64
# Nombre: Campera, Precio: $34.00, Cantidad: 22
# Nombre: Sweater, Precio: $14.80, Cantidad: 29
# Nombre: Pollera, Precio: $18.00, Cantidad: 41
# Nombre: Camisa, Precio: $24.71, Cantidad: 0

# %%
tester.calcular_valor_inventario()
# Out:
# El valor total del inventario es de $17,473.92.

# %%
isinstance(tester, TiendaOnLine)
# Out:
# True

# %%
floristeria=TiendaOnLine("Rosa Roja")

# %%
floristeria.agregar_producto("Lirio",1.20,100)
# Out:
# El producto 'Lirio' fue agregado al inventario.
# Nombre: Lirio, Precio: $1.20, Cantidad: 100

# %%
floristeria.agregar_producto("Rosa",2.20,220)
# Out:
# El producto 'Rosa' fue agregado al inventario.
# Nombre: Lirio, Precio: $1.20, Cantidad: 100
# Nombre: Rosa, Precio: $2.20, Cantidad: 220

# %%
floristeria.actualizar_stock("ROSA",500)
# Out:
# Se actualizó el stock:
# Nombre: Rosa, Precio: $2.20, Cantidad: 720

# %%
floristeria.calcular_valor_inventario()
# Out:
# El valor total del inventario es de $1,704.00.
